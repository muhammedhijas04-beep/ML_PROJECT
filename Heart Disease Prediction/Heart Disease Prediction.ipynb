# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
heart=pd.read_csv("data\heart.csv")
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
print("shape:\n",heart.shape)
print("\nData type:\n",heart.dtypes)
print("\nNumber of null values\n:\n",heart.isnull().sum())
print("\nNumber of duplicate values\n:\n",heart.duplicated().sum())
print("\nMemory:\n",heart.info())
print("\nDescribe the data:\n",heart.describe(include="all"))
# Out:
# shape:
#  (1025, 14)
#
# Data type:
#  age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object
#
# Number of null values
# :
#  age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
#
# Number of duplicate values
# :
#  723
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
#
# Memory:
#  None
#
# Describe the data:
#                 age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
heart=heart.drop_duplicates()

# %%
duplicate_rows = heart[heart.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")
# Out:
# Number of duplicate rows: 0

# %%
heart.shape
# Out:
# (302, 14)

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# target   -0.221476 -0.283609  0.432080 -0.146269 -0.081437 -0.026826
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.111590 -0.395235  0.093216  0.206040 -0.164124  0.302261
# sex      -0.060351 -0.046439  0.143460  0.098322 -0.032990  0.113060
# cp        0.041561  0.293367 -0.392937 -0.146692  0.116854 -0.195356
# trestbps -0.115367 -0.048023  0.068526  0.194600 -0.122873  0.099248
# chol     -0.147602 -0.005308  0.064099  0.050086  0.000417  0.086878
# fbs      -0.083081 -0.007169  0.024729  0.004514 -0.058654  0.144935
# restecg   1.000000  0.041210 -0.068807 -0.056251  0.090402 -0.083112
# thalach   0.041210  1.000000 -0.377411 -0.342201  0.384754 -0.228311
# exang    -0.068807 -0.377411  1.000000  0.286766 -0.256106  0.125377
# oldpeak  -0.056251 -0.342201  0.286766  1.000000 -0.576314  0.236560
# slope     0.090402  0.384754 -0.256106 -0.576314  1.000000 -0.092236
# ca       -0.083112 -0.228311  0.125377  0.236560 -0.092236  1.000000
# thal     -0.010473 -0.094910  0.205826  0.209090 -0.103314  0.160085
# target    0.134874  0.419955 -0.435601 -0.429146  0.343940 -0.408992
#
#               thal    target
# age       0.065317 -0.221476
# sex       0.211452 -0.283609
# cp       -0.160370  0.432080
# trestbps  0.062870 -0.146269
# chol      0.096810 -0.081437
# fbs      -0.032752 -0.026826
# restecg  -0.010473  0.134874
# thalach  -0.094910  0.419955
# exang     0.205826 -0.435601
# oldpeak   0.209090 -0.429146
# slope    -0.103314  0.343940
# ca        0.160085 -0.408992
# thal      1.000000 -0.343101
# target   -0.343101  1.000000

# %%
corr=heart.corr(numeric_only=True)
print("correletion metrix:",corr)
plt.figure(figsize=(13,10))
sns.heatmap(corr,annot=True,cmap="winter")
plt.savefig("correletion heatmap")
plt.show()
# Out:
# correletion metrix:                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# target   -0.221476 -0.283609  0.432080 -0.146269 -0.081437 -0.026826
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.111590 -0.395235  0.093216  0.206040 -0.164124  0.302261
# sex      -0.060351 -0.046439  0.143460  0.098322 -0.032990  0.113060
# cp        0.041561  0.293367 -0.392937 -0.146692  0.116854 -0.195356
# trestbps -0.115367 -0.048023  0.068526  0.194600 -0.122873  0.099248
# chol     -0.147602 -0.005308  0.064099  0.050086  0.000417  0.086878
# fbs      -0.083081 -0.007169  0.024729  0.004514 -0.058654  0.144935
# restecg   1.000000  0.041210 -0.068807 -0.056251  0.090402 -0.083112
# thalach   0.041210  1.000000 -0.377411 -0.342201  0.384754 -0.228311
# exang    -0.068807 -0.377411  1.000000  0.286766 -0.256106  0.125377
# oldpeak  -0.056251 -0.342201  0.286766  1.000000 -0.576314  0.236560
# slope     0.090402  0.384754 -0.256106 -0.576314  1.000000 -0.092236
# ca       -0.083112 -0.228311  0.125377  0.236560 -0.092236  1.000000
# thal     -0.010473 -0.094910  0.205826  0.209090 -0.103314  0.160085
# target    0.134874  0.419955 -0.435601 -0.429146  0.343940 -0.408992
#
#               thal    target
# age       0.065317 -0.221476
# sex       0.211452 -0.283609
# cp       -0.160370  0.432080
# trestbps  0.062870 -0.146269
# chol      0.096810 -0.081437
# fbs      -0.032752 -0.026826
# restecg  -0.010473  0.134874
# thalach  -0.094910  0.419955
# exang     0.205826 -0.435601
# oldpeak   0.209090 -0.429146
# slope    -0.103314  0.343940
# ca        0.160085 -0.408992
# thal      1.000000 -0.343101
# target   -0.343101  1.000000

# %%
sns.countplot(x='target',hue='target',data=heart)
plt.xticks([0,1],['no-disease','disease'])
plt.show()
plt.savefig("countplot1")

# %%
sns.countplot(data=heart,x='sex',hue='target')
plt.xticks([0,1],['female','male'])
plt.legend(['no-disease','disease'])
plt.show()
plt.savefig("countplot")

# %%
heart.hist(figsize=(12,12),edgecolor="red")
plt.savefig("featureplot")
plt.show()

# %% [markdown]
# # logistic regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

# %%
x = heart.drop("target",axis=1)
y = heart["target"]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.3,random_state=42)

# %%
model = LogisticRegression(max_iter=1000,class_weight='balanced')
model.fit(x_train,y_train)
prediction = model.predict(x_test)

# %%
model.classes_
# Out:
# array([0, 1])

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86        48
#            1       0.84      0.86      0.85        43
#
#     accuracy                           0.86        91
#    macro avg       0.86      0.86      0.86        91
# weighted avg       0.86      0.86      0.86        91

# %%
print(confusion_matrix(y_test,prediction))
# Out:
# [[41  7]
#  [ 6 37]]

# %%
model.predict_proba(x_test)
# Out:
# array([[0.14788113, 0.85211887],
#        [0.38563641, 0.61436359],
#        [0.97036716, 0.02963284],
#        [0.39105402, 0.60894598],
#        [0.4500316 , 0.5499684 ],
#        [0.99420571, 0.00579429],
#        [0.95315779, 0.04684221],
#        [0.45457177, 0.54542823],
#        [0.56373949, 0.43626051],
#        [0.70633124, 0.29366876],
#        [0.41315557, 0.58684443],
#        [0.97075674, 0.02924326],
#        [0.13442448, 0.86557552],
#        [0.30975094, 0.69024906],
#        [0.28390798, 0.71609202],
#        [0.89546751, 0.10453249],
#        [0.80876754, 0.19123246],
#        [0.14346478, 0.85653522],
#        [0.74848264, 0.25151736],
#        [0.12133843, 0.87866157],
#        [0.32825269, 0.67174731],
#        [0.59945676, 0.40054324],
#        [0.94147499, 0.05852501],
#        [0.07312175, 0.92687825],
#        [0.95525524, 0.04474476],
#        [0.9661821 , 0.0338179 ],
#        [0.03920177, 0.96079823],
#        [0.32916046, 0.67083954],
#        [0.98540633, 0.01459367],
#        [0.43040051, 0.56959949],
#        [0.18076248, 0.81923752],
#        [0.08545972, 0.91454028],
#        [0.13067091, 0.86932909],
#        [0.2724609 , 0.7275391 ],
#        [0.0572771 , 0.9427229 ],
#        [0.47635751, 0.52364249],
#        [0.52125142, 0.47874858],
#        [0.01283295, 0.98716705],
#        [0.79788024, 0.20211976],
#        [0.94055531, 0.05944469],
#        [0.7969054 , 0.2030946 ],
#        [0.96530479, 0.03469521],
#        [0.63091401, 0.36908599],
#        [0.5031245 , 0.4968755 ],
#        [0.97556737, 0.02443263],
#        [0.62184934, 0.37815066],
#        [0.13150781, 0.86849219],
#        [0.98897201, 0.01102799],
#        [0.22963977, 0.77036023],
#        [0.10879861, 0.89120139],
#        [0.58276465, 0.41723535],
#        [0.96806796, 0.03193204],
#        [0.99891956, 0.00108044],
#        [0.46190733, 0.53809267],
#        [0.36627502, 0.63372498],
#        [0.95731733, 0.04268267],
#        [0.48068887, 0.51931113],
#        [0.20187102, 0.79812898],
#        [0.67012657, 0.32987343],
#        [0.90076463, 0.09923537],
#        [0.15506866, 0.84493134],
#        [0.72902201, 0.27097799],
#        [0.99483048, 0.00516952],
#        [0.11401146, 0.88598854],
#        [0.08734272, 0.91265728],
#        [0.54148048, 0.45851952],
#        [0.29303142, 0.70696858],
#        [0.92617466, 0.07382534],
#        [0.98001792, 0.01998208],
#        [0.25578512, 0.74421488],
#        [0.9350604 , 0.0649396 ],
#        [0.02447759, 0.97552241],
#        [0.03871599, 0.96128401],
#        [0.11319817, 0.88680183],
#        [0.8530319 , 0.1469681 ],
#        [0.98596486, 0.01403514],
#        [0.43849892, 0.56150108],
#        [0.15873634, 0.84126366],
#        [0.08066168, 0.91933832],
#        [0.94852269, 0.05147731],
#        [0.98617405, 0.01382595],
#        [0.92985171, 0.07014829],
#        [0.98965851, 0.01034149],
#        [0.93465411, 0.06534589],
#        [0.10266356, 0.89733644],
#        [0.52275955, 0.47724045],
#        [0.38357952, 0.61642048],
#        [0.64277723, 0.35722277],
#        [0.9887468 , 0.0112532 ],
#        [0.01481561, 0.98518439],
#        [0.96004068, 0.03995932]])

# %% [markdown]
# # Random Forest Classifier.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score

# %%
model = RandomForestClassifier(n_estimators = 100)
model.fit(x_train,y_train)
prediction = model.predict(x_test)

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83        48
#            1       0.78      0.91      0.84        43
#
#     accuracy                           0.84        91
#    macro avg       0.84      0.84      0.84        91
# weighted avg       0.84      0.84      0.83        91

# %%
prediction = model.predict([[63, 1, 3, 145, 233, 1, 0, 150, 0, 2.3, 0, 0, 1]])
print(prediction)
# Out:
# [1]
# C:\Users\muham\Downloads\anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
